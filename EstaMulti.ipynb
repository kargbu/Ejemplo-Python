# %%
import sympy

a = sympy.simbols ("a")
b = sympy.simbols ("b")
c = sympy.simbols ("c")

# %%
# Out:
#   File "<ipython-input-1-755fb0da2dd6>", line 1
#     a * a = a
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?
